# %%
import pandas as pd

# %%
matches = pd.read_csv("match_stats.csv", index_col = 0)

# %%
matches.head()
# Out:
#          date   time     comp        round  day venue result   gf   ga  \
# 0  2024-08-17  21:30  La Liga  Matchweek 1  Sat  Away      W  2.0  1.0
# 1  2024-08-24  19:00  La Liga  Matchweek 2  Sat  Home      W  2.0  1.0
# 2  2024-08-27  21:30  La Liga  Matchweek 3  Tue  Away      W  2.0  1.0
# 3  2024-08-31  17:00  La Liga  Matchweek 4  Sat  Home      W  7.0  0.0
# 4  2024-09-15  16:15  La Liga  Matchweek 5  Sun  Away      W  4.0  1.0
#
#          opponent  ...  match report  notes  sh  sot  dist   fk pk pkatt  \
# 0        Valencia  ...  Match Report    NaN  17    5  18.6  1.0  1     1
# 1   Athletic Club  ...  Match Report    NaN  13    5  16.6  0.0  0     0
# 2  Rayo Vallecano  ...  Match Report    NaN  22    5  19.3  1.0  0     0
# 3      Valladolid  ...  Match Report    NaN  23   11  13.7  1.0  0     0
# 4          Girona  ...  Match Report    NaN  20    9  19.1  0.0  0     0
#
#   season       team
# 0   2025  Barcelona
# 1   2025  Barcelona
# 2   2025  Barcelona
# ...

# %%
matches.shape
# Out:
# (248, 28)

# %%
matches["team"].value_counts()
# Out:
# team
# Athletic Club      14
# Mallorca           14
# Real Sociedad      14
# Leganes            14
# Barcelona          12
# Girona             12
# Valencia           12
# Getafe             12
# Valladolid         12
# Sevilla            12
# Espanyol           12
# Real Betis         12
# Real Madrid        12
# Rayo Vallecano     12
# Celta Vigo         12
# Osasuna            12
# Alaves             12
# Villarreal         12
# Atletico Madrid    12
# Las Palmas         12
# Name: count, dtype: int64

# %%
matches[matches["team"] == "Real Madrid"]
# Out:
#          date   time     comp        round  day venue result   gf   ga  \
# 1  2024-08-18  21:30  La Liga  Matchweek 1  Sun  Away      D  1.0  1.0
# 2  2024-08-25  17:00  La Liga  Matchweek 2  Sun  Home      W  3.0  0.0
# 3  2024-08-29  20:30  La Liga  Matchweek 3  Thu  Away      D  1.0  1.0
# 4  2024-09-01  21:30  La Liga  Matchweek 4  Sun  Home      W  2.0  0.0
# 5  2024-09-14  21:00  La Liga  Matchweek 5  Sat  Away      W  2.0  0.0
# 7  2024-09-21  21:00  La Liga  Matchweek 6  Sat  Home      W  4.0  1.0
# 1  2024-08-18  21:30  La Liga  Matchweek 1  Sun  Away      D  1.0  1.0
# 2  2024-08-25  17:00  La Liga  Matchweek 2  Sun  Home      W  3.0  0.0
# 3  2024-08-29  20:30  La Liga  Matchweek 3  Thu  Away      D  1.0  1.0
# 4  2024-09-01  21:30  La Liga  Matchweek 4  Sun  Home      W  2.0  0.0
# 5  2024-09-14  21:00  La Liga  Matchweek 5  Sat  Away      W  2.0  0.0
# 7  2024-09-21  21:00  La Liga  Matchweek 6  Sat  Home      W  4.0  1.0
#
# ...

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1    40
# Matchweek 2    40
# Matchweek 3    40
# Matchweek 4    40
# Matchweek 5    40
# Matchweek 6    40
# Matchweek 7     8
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date              object
# time              object
# comp              object
# round             object
# day               object
# venue             object
# result            object
# gf               float64
# ga               float64
# opponent          object
# xg               float64
# xga              float64
# poss             float64
# attendance       float64
# captain           object
# formation         object
# opp formation     object
# referee           object
# match report      object
# notes            float64
# sh                 int64
# sot                int64
# dist             float64
# fk               float64
# pk                 int64
# pkatt              int64
# season             int64
# team              object
# dtype: object

# %%
del matches["comp"]

# %%
del matches["notes"]

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches.dtypes
# Out:
# date             datetime64[ns]
# time                     object
# comp                     object
# round                    object
# day                      object
# venue                    object
# result                   object
# gf                      float64
# ga                      float64
# opponent                 object
# xg                      float64
# xga                     float64
# poss                    float64
# attendance              float64
# captain                  object
# formation                object
# opp formation            object
# referee                  object
# match report             object
# notes                   float64
# sh                        int64
# sot                       int64
# dist                    float64
# fk                      float64
# pk                        int64
# pkatt                     int64
# season                    int64
# team                     object
# dtype: object

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches
# Out:
#          date   time     comp        round  day venue result   gf   ga  \
# 0  2024-08-17  21:30  La Liga  Matchweek 1  Sat  Away      W  2.0  1.0
# 1  2024-08-24  19:00  La Liga  Matchweek 2  Sat  Home      W  2.0  1.0
# 2  2024-08-27  21:30  La Liga  Matchweek 3  Tue  Away      W  2.0  1.0
# 3  2024-08-31  17:00  La Liga  Matchweek 4  Sat  Home      W  7.0  0.0
# 4  2024-09-15  16:15  La Liga  Matchweek 5  Sun  Away      W  4.0  1.0
# ..        ...    ...      ...          ...  ...   ...    ...  ...  ...
# 1  2024-08-25  19:00  La Liga  Matchweek 2  Sun  Away      L  1.0  2.0
# 2  2024-08-29  20:30  La Liga  Matchweek 3  Thu  Home      D  1.0  1.0
# 3  2024-09-01  17:00  La Liga  Matchweek 4  Sun  Away      L  0.0  2.0
# 4  2024-09-15  17:30  La Liga  Matchweek 5  Sun  Home      L  2.0  3.0
# 5  2024-09-21  16:15  La Liga  Matchweek 6  Sat  Away      L  1.0  2.0
#
#           opponent  ...  notes  sh  sot  dist   fk pk pkatt season  \
# ...

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches
# Out:
#          date   time     comp        round  day venue result   gf   ga  \
# 0  2024-08-17  21:30  La Liga  Matchweek 1  Sat  Away      W  2.0  1.0
# 1  2024-08-24  19:00  La Liga  Matchweek 2  Sat  Home      W  2.0  1.0
# 2  2024-08-27  21:30  La Liga  Matchweek 3  Tue  Away      W  2.0  1.0
# 3  2024-08-31  17:00  La Liga  Matchweek 4  Sat  Home      W  7.0  0.0
# 4  2024-09-15  16:15  La Liga  Matchweek 5  Sun  Away      W  4.0  1.0
# ..        ...    ...      ...          ...  ...   ...    ...  ...  ...
# 1  2024-08-25  19:00  La Liga  Matchweek 2  Sun  Away      L  1.0  2.0
# 2  2024-08-29  20:30  La Liga  Matchweek 3  Thu  Home      D  1.0  1.0
# 3  2024-09-01  17:00  La Liga  Matchweek 4  Sun  Away      L  0.0  2.0
# 4  2024-09-15  17:30  La Liga  Matchweek 5  Sun  Home      L  2.0  3.0
# 5  2024-09-21  16:15  La Liga  Matchweek 6  Sat  Away      L  1.0  2.0
#
#           opponent  ...  sh  sot  dist   fk pk pkatt season        team  \
# ...

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex = True).astype("int")# replaces the : inside of the time giving the algorithm a time code so that python can read it

# %%
matches["day_code"] = matches["date"].dt.dayofweek # sets the day to a number of the week

# %%
matches
# Out:
#          date   time     comp        round  day venue result   gf   ga  \
# 0  2024-08-17  21:30  La Liga  Matchweek 1  Sat  Away      W  2.0  1.0
# 1  2024-08-24  19:00  La Liga  Matchweek 2  Sat  Home      W  2.0  1.0
# 2  2024-08-27  21:30  La Liga  Matchweek 3  Tue  Away      W  2.0  1.0
# 3  2024-08-31  17:00  La Liga  Matchweek 4  Sat  Home      W  7.0  0.0
# 4  2024-09-15  16:15  La Liga  Matchweek 5  Sun  Away      W  4.0  1.0
# ..        ...    ...      ...          ...  ...   ...    ...  ...  ...
# 1  2024-08-25  19:00  La Liga  Matchweek 2  Sun  Away      L  1.0  2.0
# 2  2024-08-29  20:30  La Liga  Matchweek 3  Thu  Home      D  1.0  1.0
# 3  2024-09-01  17:00  La Liga  Matchweek 4  Sun  Away      L  0.0  2.0
# 4  2024-09-15  17:30  La Liga  Matchweek 5  Sun  Home      L  2.0  3.0
# 5  2024-09-21  16:15  La Liga  Matchweek 6  Sat  Away      L  1.0  2.0
#
#           opponent  ...  dist   fk  pk  pkatt season        team venue_code  \
# ...

# %%
matches["target"] = (matches["result"] == "W").astype("int") #converts end result of matches to int's

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators = 50, min_samples_split = 10, random_state = 1)

# %%
train = matches[matches["date"] < '2024-09-01']

# %%
test = matches[matches["date"] > '2024-09-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score # how accurate is this

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.5217391304347826

# %%
combined = pd.DataFrame(dict(actual = test["target"], predicted = preds))

# %%
pd.crosstab(index = combined["actual"], columns = combined["predicted"]) #a two way table to what happens when predicted a 0 or 1
# Out:
# predicted   0   1
# actual
# 0          34  18
# 1          26  14

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds) #when we predicted a win how close did we actually win
# Out:
# 0.4375

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Real Madrid").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed = 'left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset = new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#         date   time     comp        round  day venue result   gf   ga  \
# 2 2024-08-25  17:00  La Liga  Matchweek 2  Sun  Home      W  3.0  0.0
# 3 2024-08-29  20:30  La Liga  Matchweek 3  Thu  Away      D  1.0  1.0
# 3 2024-08-29  20:30  La Liga  Matchweek 3  Thu  Away      D  1.0  1.0
# 4 2024-09-01  21:30  La Liga  Matchweek 4  Sun  Home      W  2.0  0.0
# 4 2024-09-01  21:30  La Liga  Matchweek 4  Sun  Home      W  2.0  0.0
# 5 2024-09-14  21:00  La Liga  Matchweek 5  Sat  Away      W  2.0  0.0
# 5 2024-09-14  21:00  La Liga  Matchweek 5  Sat  Away      W  2.0  0.0
# 7 2024-09-21  21:00  La Liga  Matchweek 6  Sat  Home      W  4.0  1.0
# 7 2024-09-21  21:00  La Liga  Matchweek 6  Sat  Home      W  4.0  1.0
#
#         opponent  ...  day_code  target  gf_rolling  ga_rolling sh_rolling  \
# 2     Valladolid  ...         6       1    1.666667    0.666667  14.333333
# 3     Las Palmas  ...         3       0    2.333333    0.333333  15.666667
# ...

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                    date   time        round  day venue result   gf   ga  \
# team
# Alaves     1 2024-08-25  19:15  Matchweek 2  Sun  Home      D  0.0  0.0
#            2 2024-08-28  21:30  Matchweek 3  Wed  Away      W  2.0  1.0
#            2 2024-08-28  21:30  Matchweek 3  Wed  Away      W  2.0  1.0
#            3 2024-09-01  17:00  Matchweek 4  Sun  Home      W  2.0  0.0
#            3 2024-09-01  17:00  Matchweek 4  Sun  Home      W  2.0  0.0
# ...                 ...    ...          ...  ...   ...    ...  ...  ...
# Villarreal 3 2024-08-31  21:30  Matchweek 4  Sat  Away      D  1.0  1.0
#            4 2024-09-14  14:00  Matchweek 5  Sat  Away      W  2.0  1.0
#            4 2024-09-14  14:00  Matchweek 5  Sat  Away      W  2.0  1.0
#            5 2024-09-22  18:30  Matchweek 6  Sun  Home      L  1.0  5.0
#            5 2024-09-22  18:30  Matchweek 6  Sun  Home      L  1.0  5.0
#
#                    opponent   xg  ...  day_code  target  gf_rolling  \
# ...

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2024-09-01']
    test = data[data["date"] > '2024-09-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined.head(10)
# Out:
#     actual  predicted       date           team    opponent result
# 5        0          0 2024-09-14         Alaves    Espanyol      L
# 6        0          1 2024-09-14         Alaves    Espanyol      L
# 7        1          0 2024-09-20         Alaves     Sevilla      W
# 8        1          1 2024-09-20         Alaves     Sevilla      W
# 14       1          0 2024-09-15  Athletic Club  Las Palmas      W
# 15       1          0 2024-09-15  Athletic Club  Las Palmas      W
# 16       1          0 2024-09-19  Athletic Club     Leganés      W
# 17       1          1 2024-09-19  Athletic Club     Leganés      W
# 18       1          1 2024-09-22  Athletic Club  Celta Vigo      W
# 19       1          1 2024-09-22  Athletic Club  Celta Vigo      W

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"AtlÃ©tico Madrid": "Atletico Madrid", "LeganÃ©s": "Leganes", "AlavÃ©s": "Alaves"}
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       date         team_x  opponent_x result_x  \
# 0           1            0 2024-09-15  Athletic Club  Las Palmas        W
# 1           1            0 2024-09-15  Athletic Club  Las Palmas        W
# 2           1            0 2024-09-15  Athletic Club  Las Palmas        W
# 3           1            0 2024-09-15  Athletic Club  Las Palmas        W
# 4           1            0 2024-09-19  Athletic Club     Leganés        W
# ..        ...          ...        ...            ...         ...      ...
# 139         1            0 2024-09-14     Villarreal    Mallorca        W
# 140         0            0 2024-09-22     Villarreal   Barcelona        L
# 141         0            0 2024-09-22     Villarreal   Barcelona        L
# 142         0            0 2024-09-22     Villarreal   Barcelona        L
# 143         0            0 2024-09-22     Villarreal   Barcelona        L
#
#         new_team_x  actual_y  predicted_y      team_y     opponent_y result_y  \
# ...

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    17
# 0     1
# Name: count, dtype: int64

# %%
17/18
# Out:
# 0.9444444444444444

# %%
error
# Out:
# 0.6551724137931034
